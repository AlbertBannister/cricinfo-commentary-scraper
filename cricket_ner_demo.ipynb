# %% [markdown]
# <a href="https://colab.research.google.com/github/AlbertBannister/cricinfo-commentary-scraper/blob/main/cricket_ner_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 56.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.19.0-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 41.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 105.9 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 37.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.35.0

# %%
from transformers import AutoModelForTokenClassification, AutoTokenizer, pipeline
from pathlib import Path
import pandas as pd

drive_path = Path("/content/drive/MyDrive")
model_path = drive_path / "my_models/cricket_ner_bert_after_pretraining_v0"

# %%
df = pd.read_csv(drive_path / "Colab Notebooks/data/NLP/inference_demo.csv", index_col=0)
data = df.text.to_list()
df.head(5)
# Out:
#                                 match_slug  \
# 0  west-indies-vs-pakistan-1st-t20i-645645
# 1  west-indies-vs-pakistan-1st-t20i-645645
# 2  west-indies-vs-pakistan-1st-t20i-645645
# 3  west-indies-vs-pakistan-1st-t20i-645645
# 4  west-indies-vs-pakistan-1st-t20i-645645
#
#                                                 text  inningNumber  \
# 0  flighted offbreak, neatly punched to long-on f...             1
# 1  drills the first ball he faces down the ground...             1
# 2  beaten in the flight, and we have timbahhhhh. ...             1
# 3                   full and flat, defended to cover             1
# 4                pushed wide of mid-off for a single             1
#
#    oversUnique  oversActual  overNumber  ballNumber  batsmanRuns  legbyes  \
# 0         0.01          0.1           1           1            1        0
# 1         0.02          0.2           1           2            1        0
# 2         0.03          0.3           1           3            0        0
# 3         0.04          0.4           1           4            0        0
# 4         0.05          0.5           1           5            1        0
#
#    byes  wides  noballs  isFour  isSix  isWicket  dismissalType  wagonX  \
# 0     0      0        0   False  False     False              0     206
# 1     0      0        0   False  False     False              0     138
# 2     0      0        0   False  False      True              2       0
# 3     0      0        0   False  False     False              0     110
# 4     0      0        0   False  False     False              0     116
#
#    wagonY  wagonZone  length
# 0     329          4      52
# 1     328          5      83
# 2       0          0     246
# 3     159          7      32
# 4     226          6      35

# %%
labels = [
    "SHOT",
    "DELIVERY",
    "LINE",
    "LENGTH"
    ]
tag2id = {tag: i+1 for i, tag in enumerate(labels)}
id2tag = {v:k for k, v in tag2id.items()}
id2tag
# Out:
# {1: 'SHOT', 2: 'DELIVERY', 3: 'LINE', 4: 'LENGTH'}

# %%
label2id = {
    'O': 0,
    **{f'B-{k}': 2*v - 1 for k, v in tag2id.items()},
    **{f'I-{k}': 2*v for k, v in tag2id.items()}
}
id2label = {v:k for k, v in label2id.items()}
id2label
# Out:
# {0: 'O',
#  1: 'B-SHOT',
#  3: 'B-DELIVERY',
#  5: 'B-LINE',
#  7: 'B-LENGTH',
#  2: 'I-SHOT',
#  4: 'I-DELIVERY',
#  6: 'I-LINE',
#  8: 'I-LENGTH'}

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModelForTokenClassification.from_pretrained(
    model_path,
    id2label=id2label,
    label2id=label2id,
)

# %%
# Replace this with your own checkpoint
token_classifier = pipeline(
    "token-classification", model=model, tokenizer=tokenizer, aggregation_strategy="simple", device=0
)

# %%
preds = token_classifier(data)
preds[:5]
# Out:
# [[{'entity_group': 'LENGTH',
#    'score': 0.9992643,
#    'word': 'flighted',
#    'start': 0,
#    'end': 8},
#   {'entity_group': 'DELIVERY',
#    'score': 0.99837303,
#    'word': 'offbreak',
#    'start': 9,
#    'end': 17},
#   {'entity_group': 'SHOT',
#    'score': 0.99967396,
#    'word': 'punched',
#    'start': 26,
#    'end': 33}],
#  [{'entity_group': 'SHOT',
#    'score': 0.99965775,
#    'word': 'drills',
#    'start': 0,
#    'end': 6}],
#  [{'entity_group': 'DELIVERY',
#    'score': 0.9485887,
#    'word': 'flight',
#    'start': 14,
#    'end': 20},
#   {'entity_group': 'SHOT',
#    'score': 0.99765444,
#    'word': 'shortens',
#    'start': 97,
#    'end': 105},
#   {'entity_group': 'LENGTH',
#    'score': 0.9963894,
#    'word': 'length',
#    'start': 110,
#    'end': 116},
#   {'entity_group': 'DELIVERY',
#    'score': 0.9985881,
#    'word': 'offbreak',
#    'start': 191,
#    'end': 199},
#   {'entity_group': 'DELIVERY',
#    'score': 0.940809,
#    'word': 'turn',
#    'start': 218,
#    'end': 222},
#   {'entity_group': 'LINE',
#    'score': 0.9986398,
#    'word': 'off stump',
#    'start': 237,
#    'end': 246}],
#  [{'entity_group': 'LENGTH',
#    'score': 0.99964416,
#    'word': 'full',
#    'start': 0,
#    'end': 4},
#   {'entity_group': 'DELIVERY',
#    'score': 0.9983039,
#    'word': 'flat',
#    'start': 9,
#    'end': 13},
#   {'entity_group': 'SHOT',
#    'score': 0.99969375,
#    'word': 'defended',
#    'start': 15,
#    'end': 23}],
#  [{'entity_group': 'SHOT',
#    'score': 0.9995505,
#    'word': 'pushed',
#    'start': 0,
#    'end': 6}]]

# %%
for text, prediction in zip(data, preds):
  print(text)
  label_pretty = [" " for _ in range(len(text))]
  for label in prediction:
    label_pretty[label["start"]: label["end"]] = ["-" for _ in range(label["end"] - label["start"])]
    label_pretty[label["end"] - 1] = "|"
    label_pretty[label["start"]: label["start"] + len(label["entity_group"])] = [c for c in label["entity_group"]]


  print("".join(label_pretty))
# Out:
# flighted offbreak, neatly punched to long-on for one
# LENGTH-| DELIVERY         SHOT--|
# drills the first ball he faces down the ground. There is a long-on in place, though
# SHOT-|
# beaten in the flight, and we have timbahhhhh. Hafeez has seen Charles advancing, I think, and he shortens his length. Charles still appears in charge, but he plays the defensive shot for the offbreak. The ball doesn't turn, and hits the off stump
#               DELIVERY                                                                           SHOT---|     LENGTH                                                                           DELIVERY                   DELIVERY           LINE----|
# full and flat, defended to cover
# LENGTH   DELIVESHOT---|
# pushed wide of mid-off for a single
# SHOT-|
# on a length, just outside off, defended off the front foot
#      LENGTH       LINE------|  SHOT---|
# Samuels stays back to a length ball, drives it to cover
#                         LENGTH       SHOT-|
# short, wide, pretty easy, and cut away to the right of backward point
# LENGTH LINE                   SHOT
# short of a length, on the stumps, Samuels still manages to open the face and guide it to third man
# LENGTH----------|         LINE-|                           SHOT--------|     SHOT|
# goes full and fast but also goes too straight, and Gayle nudges it down to fine leg
#      LENGTH   DELIVERY               LINE---|            SHOT-|
# short of a length, rising towards the chest, defended in front of the chest
# LENGTH----------|  DELIVERY                  SHOT---|
# full, on off, defended from the crease
# LENGTH   LINE SHOT---|
# full, offbreak, played back to him
# LENGTHDELIVERY  SHOT-|
# short of a length, flicked to short midwicket where Afridi's footwork keeps them pinned at their ends
# LENGTH----------|  SHOT--|
# topspinner, around off, defended back
# DELIVERY-|         LINE SHOT---|
# slower, offbreak, seems to have beaten the inside edge and gone for a leg-bye to short fine
# DELIVERYDELIVERY
# Gayle won't be hitting into the sea tonight. Hafeez has got him. Hafeez stays full and around middle and off, Gayle plays a defensive, but the bat is either hidden behind or is playing for an offbreak. This one goes with the angle, and Gayle seems pretty plumb despite that big stride of his
#                                                                               LENGTH          LINE---------|                                                                                    DELIVERY
# flighted outside off, defended off the front foot
# LENGTH-| LINE------|  SHOT---|
# short, not too wide, beats his cut with a little extra bounce
# LENGTH         LINE            SHOT              DELIVERY---|
# nice shot. This time Samuels makes a slight forward movement, but stands tall as Irfan pitches short and cuts this through point
#                                             DELIVERY-------|                                             SHOT
# Doesn't matter the number of fielders. Samuels has split those three fielders in the point region. Backs away a little to create his own room and cut this from the line of off
#                                                                                                                                                   SHOT
# Irfan might have gone round the stumps but he is still pitching short, and has been cut away again. This time, though, Shehzad does the fielding at backward point
#                       DELIVERY-------|                          LENGTH              SHOT
# spongy bounce this time on the shortish ball. Might have been the slower ball too. Beats his push
# DELIVDELIVERY                  LENGTH-|                           DELIVERY--|                SHOT
# this time Samuels says you can stack that point region all you want, because I can go over them too. Rises with the bounce, takes this from chest-high, and upper-cuts it over point
#                                                                                                      DELIVERY                                               SHOT-----|
# goes wide of the crease, angles one in, beats the inside edge, hits the pad, but is headed down leg
#                          DELIVERY----|                         LINE-------|
# not a warm welcome to Babar. He goes wide of the crease again, doesn't try to turn the ball much, and Simmons plays the pick-up shot to send this length ball over wide long-on
#                                                                                                                                         SHOT      LENGTH
# angling in, defended again
# LINE-----|  SHOT---|
# now that one has turned. And the top of off has been hit. Extra revs on this. Babar might have dragged this a little short, but the ball rips away after pitching middle and off, squares Simmons up, and bowls him. Beats him by a long distance too. Bear in mind he is bowling from wide of the crease
#                                         LINE                                                                         LENGTH              DELIVERY|                LINE---------|
# fires into the pads from his wide angle, at 86ks, nicely deflected away fine of short fine leg
#       LINE---| LINE
# flighted, but this doesn't turn and hits the inside half of the defensive bat
# LENGTH-|                DELIVERY
# shortish offbreak, defended in front of off
# LENGTH-| DELIVERY  SHOT---|             LINE
# flighted, another offbreak, but this one doesn't turn as much as he expects, and is beaten on the outside edge
# LENGTH-|          DELIVERY               DELIVERY---|
# stays back to a length-ball offbreak, and nearly chops on
#                 LENGTH      DELIVERY             SHOT|
# one-handed cover-drive against the turn. This time Samuels finally presses forward, and as he drives this offbreak, the top hand comes off the handle, but he has found the timing and the placement
#                  SHOT|                                                                        SHOT-|      DELIVERY
# flatter, on off, defended back to him
# DELIVERY    LINE SHOT---|
# tossed up outside off, pushed to cover. Wants one but realises he has hit straight to the fielder
# LENGTH--| LINE------|  SHOT-|
# Bravo plays for the turn, the ball doesn't, hits the inside half of the bat for a single
#
# huge wicket on debut. Samuels has been hitting every bowler around. And he has been caught-and-bowled. What a debut for Babar. Samuels, like he did with Afridi during the ODIs, charges down, takes this on a half-volley and drills one down the ground. This time, though, he has hit it straight back at Babar, who is alert and quick to take it with both hands. Comes at a comfortable height but an uncomfortable pace. He has hurt his left hand while taking the catch
#                                                                                                                                                                                  SHOT--|                       LENGTH----|     SHOT-|
# Pollard hits back first ball. Length ball, flat, middle and leg, and Pollard drives this between the bowler and mid-on
#                               LENGTH       DELIVELINE---------|              SHOT-|
# and had mid-on not been moved back, this would have been an easy catch for him. Pollard drives again, powerfully so, but he can't keep it down. Bounces short of long-on. They take only one despite a diving save at the boundary
#                                                                                         SHOT-|
# sharp turn now. Only the second one he has turned today, but that's all you need in T20 if you are accurate. Beaten
# DELIVERY-|
# more dozey running. Hit wide of deep cover, but they take just the one
#                     SHOT
# short of a length, outside off, punched to deep cover for one
# LENGTH----------|  LINE------|  SHOT--|
# appeal for pad first as this has been fired in at 102ks. Would have been plumb had Pollard not got an inside edge
#                                       DELIVERY
# flighted into the pads, worked away to deep midwicket
# LENGTH-| LINE--------|  SHOT-|
# tossed up, middle and leg, holds its line, hits the pad
# LENGTH--|  LINE---------|  DELIVERY-----|  LINE-------|
# more unsure running between the Trini boys. This legbreak hits the inside half of the bat, doesn't go too far off the wicket, but Pollard makes a late decision to call him through. Umar Akmal can't hit the stumps at the non-striker's end otherwise we would have had a close appeal
#                                                  DELIVERY                                        DELIVERY
# Pollard is not looking comfortable against Afridi. With cement feet he defends a legbreak to cover
#                                                                        SHOT--|   DELIVERY
# pushed wide of point for one
# SHOT-|
# length ball, on off, defended to cover
# LENGTH          LINE SHOT---|
# Pollard nearly gets himself out. He is not backing himself to play solid cricket. Throws his arms at a length ball, in front of his body, and skies it towards cover. It falls short of the fielder, though
#                                                                                                        LENGTH                                 SHOT|
# this one turns, and past the edge it goes
#          DELIVERY
# arm ball, Pollard plays a late dab, gets a single to short third. Finally, some smooth running
# DELIVERY                       SHOT
# flighted outside off, holds its line, bounces too, ad beats the outside edge
# LENGTH-| LINE------|  DELIVERY-----|  DELIVERY
# cement feet again. Pollard just throws his bat at another, and gets an inside edge to short fine leg
#
# flighted, on middle and leg, this time he bunts it to leg for one
# LENGTH-|     LINE---------|               SHOT|
# quick legbreak, but a little short. Punched to long-off for one
# DELIVEDELIVERY               LENGTH SHOT--|
# driven to deep cover for one
# SHOT-|
# he has nudged this to leg, from middle and off. That excites the fielders a bit
#        SHOT-|                   LINE---------|
# finally an overpitched delivery, and that is in Pollard's zone. He has smoked it clean back over Afridi's head.
#            LENGTH----|                                                 SHOT-|
# sharp offbreak, cramps him up. Defended
# DELIVEDELIVERY                 SHOT---|
# Jamshed misfields at the boundary. Punched to the right of deep point, Jamshed gets there, but is slow in getting down
#                                    SHOT--|
# another offbreak that doesn't turn as much as expected, and beats the outside edge
#         DELIVERY      DELIVERY---|
# fuller, flatter, hits the pad, deflects to the keeper
# LENGTH  DELIVERY LINE-------|
# defended back to him
# SHOT---|
# flat offbreak, played back to him
# DELIVERY----|  SHOT-|
# quick legbreak, Pollard is a little surprised. Goes off the outside half of the bat for one
# DELIVEDELIVERY
# another quick legbreak, wide outside off, beats his drive, but goes for two byes off Akmal's glove
#         DELIVEDELIVERY  LINE-----------|            SHOT|
# short of a length, outside off, punched to deep point
# LENGTH----------|  LINE------|  SHOT--|
# short of a length, turns from outside leg to outside off, punched into the deep
# LENGTH----------|             LINE------|    LINE------|  SHOT--|
# flighted on middle and leg, bunted into the leg side, towards deep midwicket, they come back for two. Afridi is not happy with the fielders. "Tum toh jawan ladke ho yaar," Afridi tells them all. [You are young boys. Should do better.]
# LENGTH-|    LINE---------|  SHOT-|
# chipped over cover for a single
# SHOT--|
# flighted outside off, opens the face, gets a single to Irfan at short third man
# LENGTH-| LINE------|  SHOT---------|
# Pollard fumbles in the dark. The ball doesn't turn, and angles past the defensive bat
#                                            DELIVERY     DELIVERY
# flat offbreak, punched to midwicket for one
# DELIVERY----|  SHOT--|
# full, flat, outside off, defended to cover. Pollard, who is not looking, is hit on the shoulder. The throw is soft, though
# LENGTHDELIVELINE------|  SHOT---|                                               LINE----------|
# short of a length, outside off, played with an open face for one
# LENGTH----------|  LINE------|  SHOT-|
# just a flick but this is a half-volley, and Pollard doesn't spare half-volleys. Drilled back over Ajmal's head
#        SHOT|               LENGTH----|                            LENGTH----|   SHOT--|
# short of a length, outside off, just holds its line, beats his late-cut
# LENGTH----------|  LINE------|                 DELIVERY             SHOT
# flat, on off, worked to leg for one
# DELIVERY LINE SHOT-|
# quick, goes with the arm, punched to long-on for one
# DELIVERY                  SHOT--|
# tossed up on middle and off, doesn't turn enough, hits the inside half of the bat for one
# LENGTH--|    LINE---------|       DELIVERY
# slower, but a little short, and has been punched away nicely, with the turn, and past point for two
# DELIVERY             LENGTH              SHOT--|
# tossed up wide, Pollard drives with no feet, and is beaten. Afridi's allotment is over. Run-a-ball and wicketless
# LENGTH--| LINE          SHOT-|
# short of a length, on off, defended
# LENGTH----------|     LINE SHOT---|
# short-arm pull. Lovely flair-full shot, but Bravo has presumed this has gone for four. Amin surprises him with a dive at deep midwicket. And the Trini boys have just taken one presuming it has gone for four
# LENGTSHOT SHOT               LENGTH
# full and on off, pushed back to him
# LENGTH      LINE SHOT-|
# full, angling into the pads, nicely wristed away through square leg for four. Pollard has punished everything that has been loose today
# LENGTH        LINE--------|         SHOT--|
# short of a length, stays low, beats his pull, draws an lbw appeal, but it is still bouncing over
# LENGTH----------|  DELIVERY|            SHOT
# dug in short again, Bravo is in the air trying to work this to leg. Is beaten, but takes the leg-bye
#        LENGTH                                     SHOT
# and he gets turn and bounce as he bowls slowly, and beats his outside edge
#             DELIVERY DELIVERY           DELIVERY
# this one angles in, goes off the inside half of the bat
#          DELIVERY|
# short of a length, turning away, punched down to long-off for one
# LENGTH----------|  DELIVERY---|  SHOT--|
# short again, but this time he finds the straight extra cover
# LENGTH
# Bravo tries a really difficult shot. The back-foot drive over cover for six. If there is any man who hits it in today's cricket, it is Bravo. This time, though, he has taken on too much even though he has hit it with the wind. Ajmal moves to his right at deep cover to complete the catch. Taken over his shoulder with the wind taking the ball away
#                                                    SHOT|
# this one doesn't turn, angles in, beats the inside edge, hits his pad. Superb debut for Babar: 4-0-23-3
#               DELIVERY DELIVERY|                         LINE-------|
# short of a length, just outside off, defended to cover
# LENGTH----------|       LINE------|  SHOT---|
# Sammy looks to pull, gets a bottom edge onto the hip
#                SHOT
# yorker. Accurate. Dug out. Perfect delivery
# LENGTH  DELIVERY  SHOT--|
# lucky runs. Pollard swings and swings hard, but all he manages is an inside edge that drags this from wide outside off to send it fine of short fine leg
#                     DELIVERY   DELIVERY                                               SHOT|           LINE-----------|
# short of a length, into the pads, tucked away for a single
# LENGTH----------|  LINE--------|  SHOT-|
# swirling hit. That is some power. This is a half-volley. Sammy goes deep into the crease to bulldoze it back. Starts on the leg side of the stumps at the non-striker's end, but swerves so much with the force that it ends up at long-off
# DELIVERY SHOT                               LENGTH----|                                         SHOT                                                                               SHOT|
# Pakistan don't want this. Offbreak that starts outside leg, and turns enough to beat Akmal to go for five wides
#                           DELIVERY             LINE------|      DELIVERY
# pushed wide of cover for one
# SHOT-|
# flighted outside off, angles away to beat the outside edge
# LENGTH-| LINE------|  DELIVERY--|
# shortish, tucked away off the hip
# LENGTH-|  SHOT-|      LINE------|
# stays back to a full offbreak. Gets a single into the midwicket region
#                 LENGTDELIVERY
# doosra. Starts outside leg. Sammy picks it only off the pitch. Defends
#                LINE------|                                     SHOT--|
# short of a length, quick, angling away, beats Sammy's attempt at punching this into the off side
# LENGTH----------|  DELIVERLINE-------|                           SHOT---|
# full, angling in, mowed to deep midwicket
# LENGTHLINE-----|  SHOT|
# Sammy has picked the slower ball early, sized it up, and smoked it out. He pushes the weight onto the back foot, gets under the length ball, and smashes this over wide long-on. Somebody return the ball please
#                      DELIVERY--|        LENGTH           SHOT-|            SHOT-|                                               LENGTH           SHOT--|
# wide full toss. This is clearly a wide, but Nero raises the batsmen's eyebrows by calling it very late
# LINE LENGTH--|                    LINE
# another full toss but this time it is closer to off, and does the job well: to stay away from Sammy, who is backing away
#         LENGTH--|                               LINE
# dropped by Amin. This is full, into the pads, and has been lofted towards the cow corner. Amin comes around from deep midwicket, the catch is high to his left, but he has parried it over the bar
#                          LENGTHLINE--------|               SHOT-|
# Junaid looks to go full and wide as Sammy looks to back away, but the batsman does well to drill this wide of cover for four
#                    LENGTH   LINE                                                           SHOT|
# slower ball, bunted into the leg side, straight to deep midwicket, but Sammy is one of the best with converting ones into twos. He puts his head down, and takes what seems a suicidal second. The throw is flat, full, stump high, and straight, but Sammy has beaten it
# DELIVERY--|  SHOT-|                                                                                                                                                                                         DELIVELENGTH                LINE---|
# short of a length, Pollard seems to be expecting it, backs away and lofts it over wide long-on for six
# LENGTH----------|                                                   SHOT|
# full toss, into the pads, wide of long-on, and even though Sammy has dropped his bat a misfield allows them a second
# LENGTH--|  LINE--------|
# finally a yorker. Dug out. Sammy is backing up a long way. He is halfway up the wicket when the ball touches bat. Easy single for him
#           LENGTH  SHOT--|                                                SHOT--------|
# yorker gone wrong. Knee-high full toss. There is no room, but somehow Sammy has lofted this clean over long-on for a six. He keeps pumping his fist after every such shot
# LENGTH                       LENGTH--|                                          SHOT-|
# this time he has gone into the wind. Irfan goes short, Sammy goes hard, and hooks with the front leg in the air. The wind holds it up, though, and he is taken at deep midwicket
#                                                 LENGTH                      SHOT|
# poor from Narine. This is hit down the ground, to the left of long-on, and there is no way the non-striker shouldn't make it for the second. Sammy would have made this comfortably. Narine is run out by a mile. Had he been as intentful as Sammy, he might have got Pollard a deserved fifty
#                           SHOT
# short of a length, on off, defended off the back foot
# LENGTH----------|     LINE SHOT---|
# short-arm pull, into, and he seems to have hit the rope on the full, but my first reaction is wrong. Takes this from short of a length, and languidly sends it over square leg. Hits the rope on the half-volley, so this will be four. I am stunned. This is given a six. Possibly a compensation for hitting into the wind and nearly making it
# LENGTSHOT SHOT                                                                                                       LENGTH----------|                                                               LENGTH----|
# big wide outside off
#     LINE-----------|
# short of a length, outside off, defended to backward point
# LENGTH----------|  LINE------|  SHOT---|
# keeps hitting into the wind. Gone. The last short-arm pull beat the deep midwicket to his left, and reached the rope on the half-volley, but this one isn't that well placed and has stood up in the wind. Simmons takes a smart catch the boundary. Can't say the same about the batting
#                                             SHOT----| SHOT                                                                  LENGTLENGTH
# short of a length, angling in, pushed into the leg side for a couple
# LENGTH----------|  LINE-----|  SHOT-|
# bunted wide of short midwicket for one
# SHOT-|
# gets turn first ball, beats him outside off
#                                 LINE------|
# googly, comes in from just outside off, dabbed to point
# DELIVERYDELIVERY           LINE------|  SHOT-|
# full, flat and straight, pushed to mid-off
# LENGTHDELIVERY LINE---|  SHOT-|
# this is not smart batting at all. Shehzad knows the two men in the deep are long-on and deep midwicket, and he still goes long-on. All he manages to do is offer a low catch to Pollard at long-on
#
# flat legbreak, on off, he lets it turn, then opens the face, and late-cuts it for four
# DELIVERY----|     LINE            DELIVERY   SHOT---------|      SHOT----|
# flat outside off again. Hafeez plays the regulation cut this time, but can't beat point
# DELIVLINE------|                         SHOT---------|
# and Amin gets four off the first ball he faces in T20Is. Gets a gift of a leg-side half-volley and clips it through midwicket
#                                                                                    LENGTH----|     SHOT|
# Amin's career strike rate stays at 400. Gabriel bowls a limp short ball, pitched outside leg, and has been pulled through leg. That short ball had no sting
#                                                              LENGTH              LINE------|               SHOT-|                   LENGTH
# short of a length, angling across, angling too far
# LENGTH----------|  LINE---------|  LINE
# short of a length, wide, punched away, but straight to short cover
# LENGTH----------|  LINE  SHOT--|
# short again, and Amin is expecting those gifts. Again not much venom behind the short ball. Dragged from around off, and through midwicket it goes
# LENGTH                                                                          LENGTH      SHOT--|             LINE
# short of a length, accurate, defended back to him
# LENGTH----------|            SHOT---|
# length ball, wide outside off, angling away too. Called
# LENGTH       LINE-----------|  LINE-------|
# short of a length, wide, punched away in front of square. Gayle makes a diving save at extra cover to keep this shot down to one run
# LENGTH----------|  LINE  SHOT--|
# googly. Pitches just outside leg, takes a leading edge, but doesn't carry back to Badree
# DELIVERY             LINE------|
# shimmies down to take this on the full and smashes this high to the right of Badree. Beats his outstretched hand
# SHOT---|                                   SHOT--|
# googly, short, pitched outside leg, punched to long-on
# DELIVERYLENGTH         LINE------|  SHOT--|
# legbreak, middle and leg, paddled to short fine for a single. Gabriel a touch sluggish there
# DELIVERY  LINE---------|  SHOT--|
# length ball, no turn, middle and leg, played to square leg
# LENGTH       LINDELIVELINE---------|  SHOT-|
# short of a length, p[itched outside leg, pushed wide of midwicket for one
# LENGTH----------|           LINE------|  SHOT-|
# starts with a short delivery and a single to deep midwicket
#               LENGTH
# carrom ball, short, wide, cut away, and misfielded by Gayle at point. poor cricket all around from West Indies on that delivery
# DELIVERY--|  LENGTH LINE  SHOT
# sharp offbreak, cramps him up. I suspect Hafeez was playing for the straighter one. Inside-edged into the pad
# DELIVEDELIVERY                                                                                   LINE
# calculated risk. Well done. Takes a length ball from wide outside off and sweeps it over square leg for four
#                                     LENGTH           LINE-----------|     SHOT-|
# looks like a soft dismissal but you can see what Hafeez was doing here. He picked the carrom ball, which shortish and widish. He tried to late-cut it, but failed to keep it down and cut him straight to short third man
#                                                                                       DELIVERY--|        LENGTH-|                         SHOT---|                                    SHOT
# short of a length, straighter one again, beats his cut
# LENGTH----------|  LENGTH---|                      SHOT
# lovely shot. Down the wicket, takes this on the half-volley, and goes over mid-off. Doesn't matter which way it is turning if you get to the pitch of the ball
#              SHOT----------|                    LENGTH----|
# flatter, non-turner. Hits his pad
# DELIVERY             LINE-------|
# another good shot by Amin. He is down the wicket again, a bit too close to the pitch of the ball, but goes ahead with the drive, and sends it between the bowler and mid-off
#                                  SHOT----------|                                                                          SHOT|
# short ball, Amin is expecting it, and rocks back to pull it over square leg for his seventh four. He has faced only 16 balls
# LENGTH                                              SHOT
# quick legbreak, defended back to him
# DELIVEDELIVERY  SHOT---|
# superb shot again. This is overpitched on off, and he has driven with this with an open face past Gayle at extra cover. And Gayle can't chase those nowadays
#                            LENGTH----|    LINE            SHOT-|
# full and straight and quick. Defended from the crease
# LENGTH   LINE---|     DELIVERSHOT---|
# heaved away from outside off, gets a single to deep midwicket
# SHOT-|           LINE------|
# length ball, pitched well outside leg, lucky to get away with just a leg-bye
# LENGTH                    LINE------|
# driven inside-out, wide of mid-off, and Samuels gives good chase to keep them down to one
# SHOT-| SHOT-----|
# full and straight, pushed to long-off for one
# LENGTH   LINE---|  SHOT-|
# short of a length, tucked into the leg side for one. This time Sammy misfields in the eagerness to go for a direct hit
# LENGTH----------|  SHOT-|
# wide and full, driven to deep cover for one
# LINE     LENGTHSHOT-|
# short of a length, pitched outside leg, pushed to Samuels
# LENGTH----------|          LINE------|  SHOT-|
# another misfield. Driven over his head, straight of long-on, and this time Badree lets it through at long-on. At least two runs gifted
#                   SHOT-|
# driven square for a single
# SHOT-|
# short of a length, turning in, helped around the corner
# LENGTH----------|  DELIVERY-|  SHOT-|
# quick offbreak, played back to him, but he wasn't in full control of that
# DELIVEDELIVERY  SHOT-|
# Akmal goes after Best. He tried that last over too, but this time he goes all out. Gets under a length ball, and drives him inside-out over mid-off
#                                                                                                 LENGTH           SHOT-|     SHOT-----|
# Sammy - who else, really? - turns it around for West Indies in the field. You couldn't imagine any other man turning this lethargic fielding effort around. Short of a length, Akmal is deep inside the crease as he pushes this towards short midwicket. He still goes for the single, Sammy has about one-and-a-half stumps to aim at. He hits. Akmal is out
#                             SHOT|                                                                                                                           LENGTH----------|                                        SHOT-|
# quick, short of a length, on off, and beats him with the angle
# DELIVERLENGTH----------|     LINE
# full, on off, runs off the outside half of the bat to third man
# LENGTH   LINE
# short of a length, just outside off, defended from the crease
# LENGTH----------|       LINE------|  SHOT---|
# full and quick, outside off, worked into the leg side for one
# LENGTH   DELIVERLINE------|  SHOT-|
# flighted outside off, defended back to him
# LENGTH-| LINE------|  SHOT---|
# full and wide, steered out to deep point for one
# LENGTH   LINE  SHOT--|
# sharp turn from short of a length and outside leg. Beats the outside edge and the off stump
# DELIVERY-|      LENGTH----------|     LINE------|                                 LINE----|
# quicker, pitched outside leg, hits the pad
# DELIVERY         LINE------|  LINE-------|
# quick full toss, hit back to Samuels. Momentum is shifting. Earlier Amin was hitting these for fours
# DELIVELENGTH--|  SHOT
# down the wicket to drive this length ball to wide of deep cover for two
# SHOT----------|    SHOT|      LENGTH
# short of a length, Azam tries to pull. Mis-hits because this is not short enough
# LENGTH----------|                SHOT
# short of a length, outside off, punched down to long-on for one
# LENGTH----------|  LINE------|  SHOT--|
# driven back at him on the up, but Sammy fields in his follow-through
# SHOT-|
# driven in the air, but well short of long-off
# SHOT-|
# length ball outside off, worked into the on side for one. Azam tries to play everything into the leg side
# LENGTH      LINE------|  SHOT-|                                         SHOT
# short of a length, on off, punched down to long-off
# LENGTH----------|     LINE SHOT--|
# Samuels has got him. Amin has walked past one. Those easy boundary balls dried up, and Amin has thrown it away. Not sure he needed to. The asking rate was in control. Down the wicket to try to drive him wide of long-off, and doesn't reach the pitch of the ball, which turns past the bat to leave him stranded
#                                                                                                                                                                        SHOT----------|           SHOT|
# is Afridi in a hurry to go swim in the sea? Down the wicket first ball, reaches the ball, and sends it sailing over long-off
#                                             SHOT----------|                                   SHOT|
# lovely drive against the turn, but Gayle makes a diving save at extra cover to keep them down to one
#        SHOT|
# paddled away to fine leg for one
# SHOT--|
# superb shot. Afridi is ON today. Backs away, makes room, takes this on the full, and drives it past extra cover for four
#                                                                        LENGTH-|      SHOT-|
# short of a length, outside off, dabbed away for a single
# LENGTH----------|  LINE------|  SHOT-|
# short of a length, quick, on off, defended with an open face
# LENGTH----------|  DELIVERY  LINE SHOT---|
# moves across the line, right in front of stumps, and flicks a full ball to long leg
#                                                      SHOT-|   LENGTH
# short of a length, quick, into the body, short-armed to long leg
# LENGTH----------|  DELIVERLENGTH------|  SHOT------|
# short of a length, on off, he looks to work it with the angle, but gets a leading edge towards extra cover
# LENGTH----------|     LINE             SHOT
# comes forward to a shortish delivery and defends
#                    LENGTH-|              SHOT--|
# length ball, outside off, pushed wide of short cover for a single
# LENGTH       LINE------|  SHOT-|
# paddled away from outside off, gets a single to short fine
# SHOT--|           LINE------|
# full, on the pads, bunted away for a single
# LENGTHLINE------|  SHOT-|
# carrom ball, outside off, opens the face to go with the turn, and takes a single
# DELIVERY--|  LINE------|  SHOT---------|
# offbreak, tossed up, just outside off, defended with an open face
# DELIVERY  LENGTH--|       LINE------|  SHOT---|
# carrom ball, pitched outside leg. Afridi hasn't picked it, wants to let it go for a wide, but the ball turns and brushes his leg
# DELIVERY--|          LINE------|                                                    LINE               DELIVERY
# driven inside-out, but Gayle makes a diving save at extra cover to keep them down to one
# SHOT-| SHOT-----|
# new spell, old loose balls. Short, without any menace behind it, and helped away over square leg for four
#                DELIVERY--|  LENGTH                                   SHOT-|
# moves across the line to work a length ball into the leg side
#                          SHOT   LENGTH
# length ball, angling into the pads, worked towards deep midwicket, and the threat of Pollard there keeps them down to one
# LENGTH               LINE--------|  SHOT-|
# poor bowling but good fielding. Well down the leg side, flicked away fine, but Badree makes a diving save at the fine-leg boundary to save two runs
#                                      LINE------------|  SHOT--|
# backs way well in advance, shows him all the stumps, but Gabriel decides to follow him. Afridi pulls to deep midwicket for one
#                                              LINE|                                             SHOT|
# wicket No. 2 for Gabriel. Pollard does his bit in the field. Not the smartest of the shots. This is the highest short ball Gabriel has bowled. Azam is nowhere near being in control of it, but goes ahead with the hook. Pollard charges in from deep square leg, and takes a low catch diving forward. This has been a match of gifts and return gifts. Still going on
#                                                                                                                 LENGTH                                                                                              SHOT
# tossed up outside off, carrom ball, beats the outside edge
# LENGTH--| LINE------|  DELIVERY--|
# a little too full, pushed to deep cover for one
#              LENGTHSHOT-|
# Afridi's international six No. 400. Down the wicket, not quite to the pitch of the ball but goes ahead with the loft. It goes as high as it goes long, but clears long-on
#                                     SHOT----------|                                                             SHOT
# carrom ball, quick, starts on off, beats the attempted dab. Afridi nods in acknowledgement
# DELIVERY--|  DELIVERY         LINE                     SHOT
# another quick carrom ball outside off, beaten again
#         DELIVEDELIVERY--| LINE------|
# Afridi keeps the strike. Stays in the crease to a length ball, opens the face, takes the single. Don't think this was the offbreak either
#                                                   LENGTH       SHOT---------|                                             DELIVERY
# short of a length, outside off, steered away for a single
# LENGTH----------|  LINE------|  SHOT--|
# quick length ball outside off, squeezes under his bat to beat him
# DELIVELENGTH      LINE------|         SHOT
# full and fast but too straight, and Babr alternates the strike again with a dink into the leg side
# LENGTH   DELIVERY     LINE---|                                              SHOT
# short of a length, angling in, Afridi gets inside the line to work it between deep fine and deep square. He nearly runs himself out by risking the second, but puts the dive in to make it. There is only half a frame there, though. And the throw was good and beside the stumps. Can't help but think a specialist keeper would have got him
# LENGTH----------|  LINE-----|                                 SHOT
# lovely shot. Makes room, takes a full and fast delivery to drive it square, over point for four. Afridi is playing a blinder here
#                                  LENGTH   DELIVERY         SHOT|
# wide down the leg side. Dug in short, middle and off, but it then seams away down the leg side
# LINE LINE------------|         LENGTH LINE---------|              DELIVERY
# length ball, outside off, played with an open face. Takes the single. No extra effort from West Indies to deny him that single, and with that strike at the start of the next over
# LENGTH       LINE------|
# half-volley outside leg, nicely placed wide of deep midwicket for two. A run a ball required now
# LENGTH----| LINE------|         SHOT-|
# on a length, on off, doesn't turn, played with an open face for one
#      LENGTH     LINE      DELIVERY SHOT-|
# Babar plants the front foot down, is beaten by the offbreak. Sammy catches at slip, but this has come off the pad only
#                                                    DELIVERY                                           LINE------|
# carrom ball outside off, beats him, but West Indies still not getting that wicket
# DELIVERY--| LINE------|
# bat-pad. This offbreak takes the inside edge, hits the pad, lobs up in the air, but far enough from the keeper
#               DELIVERY                        LINE-------|
# oh what? A reverse-sweep. And connected well too. But can't beat Best at point. So excited is Babar he nearly runs himself out by going for the single that never is
#            SHOT--------|
# big wide down the leg side, the diving Charles can only get a hand to it. That's three runs before a ball is bowled
#     LINE LINE------------|
# ...
#          LINE-------|     SHOT-|
# touch short and cuts to short third man
#       LENGTH    SHOT
# rocks back and nicely punched to off side for a single
#                       SHOT--|
# solid in defence, Haq keeping it tight
#
# fired it in and digs it out for a single
# DELIVERY        SHOT
# good looking drive but couldn't beat the sweeper at cover
#              SHOT|
# leading edge and falls safe, closing the face of the blade way too early
#                              SHOT--|
# down the track and played to covers for a single
# SHOT---------|     SHOT-|
# touch short on middle and leg, swivels and pulls to on side
#       LENGTH   LINE---------|  SHOT--|     SHOT|
# saw him coming and dropped it short, miscued pull goes over the keepers head, fortune runs
#                               LENGTH         SHOT
# length delivery on off and pushed off the back-foot for a single
# LENGTH             LINE    SHOT-|
# angled in and awkwardly fends to off side
# LINE----|               SHOT|
# fuller and wide, touch slower too and smacked to deep covers for a single
# LENGTH     LINE        DELIVERY       SHOT--|
# fuller and played along the carpet for a single
# LENGTH     SHOT-|
# length delivery outside off and under cuts to on side
# LENGTH          LINE------|           SHOT
# fuller on middle stump and chipped it over the bowlers head for a single and retains the strike
# LENGTH    LINE-------|     SHOT--|
# full toss outside off stump and  Obuya failed to reach at that
# LENGTH--| LINE------------|
# full and driven to covers for a single
# LENGTH   SHOT-|
# full and wide, in fact way too outside off and called wide
# LENGTH   LINE                  LINE------|     SHOT-| LINE
# shuffled across and smashed to long off only for a single
#                     SHOT--|
# text book stuff, fuller outside off and swatted past sweeper cover
#                  LENGTH LINE------|     SHOT--|
# touch wide and steered to third man for a couple
#       LINE     SHOT--|
# beautifully played, low full toss, bread on butter and nicely paddled it in between the fielders
#                     LENGTH------|                             SHOT--|
# nothing delivery on off stump and swept to short fine leg for a single
#                     LINE----|     SHOT|
# punched to covers
# SHOT--|
# down the track and played along the carpet for a single
# SHOT---------|
# loopy delivery on off and pushed to covers
# DELIVERY          LINE    SHOT-|
# down the track and tried to clear deep mid wicket, no where near the ball and managed to find the lone fielder at deep mid wicket
# SHOT---------|
# round the stumps and opts to sweeps, ball lobs up and just eludes short fine leg fielder
# DELIVERY-------|             SHOT-|
# angled away and played to off side
# LINE-|          SHOT-|
# width on offer and trashed to deep cover fielder
# LINE|              SHOT--|
# full outside off and edged to third man
# LENGTLINE------|     SHOT|
# fuller outside off and driven to covers
# LENGTH LINE------|     SHOT-|
# keeping it full outside off and steered to backward point
#            LENGTLINE------|     SHOT--|
# low full toss and played to long on for a single and retains the strike
# LENGTH------|     SHOT-|
# cuts and cuts it fine, beats the dive at third man region
# SHOT     SHOT
# played straight to the fielder
# SHOT-|
# on the pads and nudged to on side for a single
# LINE------|     SHOT-|
# touch quicker through the air and played back to the bowler
# SHOT| DELIVERY                    SHOT-|
# reverse sweep and beats the man at covers, useful runs
# SHOT--------|
# fuller and played along the ground for a single
# LENGTH     SHOT-|
# full and wide for round the stumps, drives to extra cover region
# LENGTH   LINE     DELIVERY-------|  SHOT-|
# drilled to long off
# SHOT--|
# nicely played, fuller outside the off stump, shuffled across and scooped it over short fine leg
#                LENGTH LINE------| LINE----|                      SHOT--|
# on the pads and nicely flicked off his boots for a couple
# LINE------|            SHOT--| LINE--------|
# full and straight on middle and leg, played along the ground for a single
# LENGTH   LINE---|    LINE---------|
# length delivery on off stump and pulled to long on for a couple
# LENGTH             LINE----|     SHOT-|
# fuller outside off and a mistimed slice to deep covers
# LENGTH LINE------|                SHOT|
# angled away and swatted to off side for a single
# LINE------|     SHOT--|
# full toss and nicely placed over point fielder
# LENGTH--|            SHOT-|
# fuller outside off and and smocked it straight, long off fielder dives but couldn't stop the ball
# LENGTH LINE------|         SHOT--|
# scooped!! beautifully executed and beats the short fine leg fielder
# SHOT--|
# turned to on side for a single
# SHOT-|
# full and wide outside off and played to backward point
# LENGTH   LINE-----------|     SHOT-|
# down the leg and called wide, untidy stuff
# LINE-------|            LINE
# length delivery on off stump and crunched to long off for a single
# LENGTH             LINE----|     SHOT---|
# fuller and hits its straight, skipper sprints for the second but fell short off his mark
# LENGTH              LINE---|
# smothered it, fuller and smocked it out of the ground
# SHOT----|     LENGTH     SHOT--|
# fuller and whacked it over mid off fielder
# LENGTH     SHOT--|
# low full toss and mistimed shot to long on for a single and gets to his fifty, well played Aga
# LENGTH------|              SHOT
# full on off stump and a miscued paddle to on side for a single
# LENGTH  LINE----|               SHOT-|
# solid in defence
#
# straying down the leg and called wide
#          LINE-------|     SHOT-|
# peach of a delivery, pitched on off and straightened enough to fox his defence
# LENGTH---|                      LINE    SHOT-------|
# erred in his line and drifted down leg
#                               LINE---|
# angled in from off stump and nudged to short fine leg for a single
# LINE----|      LINE----|     SHOT-|
# on the pads again and missed his flick, kissed his front pad and rolled to on side
# LINE------|                      SHOT|
# clever shot, back of a length delivery on off stump, used the pace of the delivery and nicely steered to third man region
#              LENGTH---------|             LINE----|                                           SHOT--|
# length delivery on off stump and punched to point
# LENGTH             LINE----|     SHOT--|
# fuller delivery on off stump and driven to mid-off
# LENGTH             LINE----|     SHOT-|
# full again and played to mid-on, no timing on that shot
# LENGTH         SHOT-|
# nice pick up shot towards deep square leg and guard stationed there keeps it for single
#      SHOT--| SHOT
# bludgeoned!! down the track and smothered it over long on
# SHOT-----|   SHOT---------|     SHOT----|
# touch fuller outside off and played to mid off for a single
#       LENGTH LINE------|     SHOT-|
# width on offer and trashed to point
# LINE|              SHOT--|
# back of a length delivery on middle and leg, plants his front foot and swatted it flat to deep mid-wicket
# LENGTH---------|             LINE---------|                            SHOT--|
# fuller delivery on off stump and tried to heave over mid-on, no timing whatsoever and finds  Ngoche at mid-on
# LENGTH             LINE----|              SHOT|
# nips back in and punched to off side
# DELIVERY---|     SHOT--|
# fends to cover
# SHOT|
# fuller on the pads and nudged to on side, Tikolo at short fine fields well
# LENGTH    LINELINE     SHOT-|
# width offered and slashed to point
# LENGTH            SHOT--|
# back of a length delivery, on midle and leg, pushes back to the bowler
# LENGTH---------|                    LINE--|  SHOT-|
# short of  alength delivery, Machan stays on his crease and powers it over midwicket region
# LENGTH-|                                                   SHOT-|
# length delivery, pitched outside off and Machan leans forward and gets it between cover and extra cover and it races away to the boundary
# LENGTH                   LINE------|
# that's the third in a row, short of a length, on middle and leg, he goes back and clears it over mid-on
#                            LENGTH----------|     LINE---------|                   SHOT-|
# length delivery, on off, touch slower, pushes it to mid-off
# LENGTH              LINE       SHOT-|  SHOT-|
# length delivery and guides to short third man
# LENGTH              SHOT-|
# caught and bowled, tossed up and timed it beautifully but straight into the hands of Ngoche
#                    LENGTH--|
# take that!! six runs over deep mid-wicket, fuller on leg stump, in the slot and thank you very much says Coetzer
#                                            LENGTH    LINE----|  LENGTH----|
# fuller on leg stump and nicely swept for a boundary
# LENGTH    LINE----|            SHOT|
# tossed up and nicely played along the carpet
# LENGTH--|
# angled in and nudged to deep mid-wicket for a single
# LINE----|     SHOT-|
# make that 16, tossed up on leg stump and handsomely swept
#               LENGTH--|    LINE----|                SHOT|
# angled in and cuts to point,  MacLeod sprints for a single but failed reach on time, big blow for Scottish
# LINE----|     SHOT
# bowled him!! what's happening here, arm delivery, comes in with the angle, tried to turn it towards mid-wicket region and it has gone through the gate
#                                     DELIVERY---|                                    SHOT
# loopy delivery on middle and leg, nudged to long on for a single
# DELIVERY          LINE---------|  SHOT-|
# turned to on side for a single
# SHOT-|
# quicker delivery on leg stump and punched to on side
# DELIVERY-------|    LINE----|     SHOT--|
# touch fuller and pushed to off side
#       LENGTH     SHOT-|
# on the pads and played along the carpet for a single
# LINE------|
# fuller on off stump and punched to covers
# LENGTH    LINE----|     SHOT--|
# back of a length delivery and cuts to off side
# LENGTH---------|              SHOT
# turned to fine leg leg region
# SHOT-|
# play and a miss, good over by the senior-pro
# SHOT
# fuller and swung his bat at that
# LENGTH     SHOT|
# that's humongous!! fuller and whacked it over mid-wicket fence
#                    LENGTH     SHOT--|
# fuller outside the off stump, shuffled across and worked to on side
# LENGTH LINE--|     LINE----|                      SHOT-|
# drilled to long on for a single
# SHOT--|
# angled in from outside off and crisply played to long off
# LINE----|      LINE------|             SHOT-|
# slower delivery around off stump channel and sensibly played along the ground
# DELIVERY------|        LINE------------|
# slower again and pushed to point
# SHOT-|           SHOT-|
# length delivery and played back to the bowler
# LENGTH              SHOT-|
# back of a length delivery and swatted to long on
# LENGTH---------|              SHOT--|
# angled in and a top edge falls safe
# LINE----|
# fullish length delivery on leg stump and drilled to on side
# LENGTH|                    LINE----|     SHOT--|
# on the pads and nudged to on side for a single
# LINE------|     SHOT-|
# fuller on off stump and crunched to long off, Patel sprints in and takes a lovely catch
# LENGTH    LINE----|     SHOT---|
# touch fuller and worked to on side for a single
#       LENGTH     SHOT-|
# back of a length delivery and a miscued pull to long on
# LENGTH---------|                        SHOT
# fuller outside the off stump, Murphy fancies a single but his partner denies
# LENGTH LINE--|     LINE----|
# shimmy down the track and a leading edge,  Odoyo back peddles a few yards and takes a smart catch. Scotland slowly slipping into a hollow
# SHOT-| SHOT---------|
# down the track  and tried to launch it out Dubai ending up getting a leading edge, Patel again makes good ground and takes a fine catch
# SHOT---------|               SHOT-|
# pushed cover
# SHOT-|
# tossed up and closed the face of the blade way too early as ball ballooned up and Aga at short mid-wicket  dives forward and takes a good catch
# LENGTH--|     SHOT----------|
# quicker delivery and fends to off side
# DELIVERY-------|     SHOT|
# tossed up and hits it straight, Varaiya settles underneath and takes a good catch
# LENGTH--|     SHOT
# on the pads and turned to on side for a single
# LINE------|     SHOT-|
# play and a miss
# SHOT
# its all over, tossed up and Wardlaw goes for the almighty swing, no where near the pitch of the ball and gets a top edge, Aga at mid-on takes a dolly
#               LENGTH--|                                   SHOT|
